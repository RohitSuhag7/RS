# %%
import pandas as pd


df = pd.read_csv("D:/Data_Stream/COVID-19DB.csv",error_bad_lines=False)
df.head()
# Out:
# b'Skipping line 7: expected 294 fields, saw 428\nSkipping line 31: expected 294 fields, saw 436\nSkipping line 40: expected 294 fields, saw 418\nSkipping line 103: expected 294 fields, saw 331\n'
#    {"created_at":"Mon Sep 07 02:11:57 +0000 2020"  id:1302791688927182848  \
# 0  {"created_at":"Mon Sep 07 02:12:08 +0000 2020"  id:1302791733328084992
# 1  {"created_at":"Mon Sep 07 02:12:20 +0000 2020"  id:1302791783626145792
# 2  {"created_at":"Mon Sep 07 02:12:28 +0000 2020"  id:1302791815423127552
# 3  {"created_at":"Mon Sep 07 02:13:23 +0000 2020"  id:1302792047016005634
# 4  {"created_at":"Mon Sep 07 02:13:26 +0000 2020"  id:1302792058172657664
#
#    id_str:"1302791688927182848"  \
# 0  id_str:"1302791733328084992"
# 1  id_str:"1302791783626145792"
# 2  id_str:"1302791815423127552"
# 3  id_str:"1302792047016005634"
# 4  id_str:"1302792058172657664"
#
#                             text:"RT @endgmez: Gente  \
# 0  text:"RT @ositobarrigon: #DNews Marvel y Squar...
# ...

# %%
df.columns
# Out:
# Index(['{"created_at":"Mon Sep 07 02:11:57 +0000 2020"',
#        'id:1302791688927182848', 'id_str:"1302791688927182848"',
#        'text:"RT @endgmez: Gente',
#        ' tudo bem? \nMeu cachorro THOR perdeu o movimento das patinhas traseiras',
#        ' e precisa de tratamento. Consegui achar um plan\u2026"',
#        'source:"\u003ca href=\"http:\/\/twitter.com\/download\/android\" rel=\"nofollow\"\u003eTwitter for Android\u003c\/a\u003e"',
#        'truncated:false', 'in_reply_to_status_id:null',
#        'in_reply_to_status_id_str:null',
#        ...
#        'id:1101980244473495552', 'id_str:"1101980244473495552".1',
#        'indices:[3', '11]}]', 'symbols:[]}.1', 'favorited:false.1',
#        'retweeted:false.1', 'filter_level:"low".1', 'lang:"pt"',
#        'timestamp_ms:"1599444717996"}'],
#       dtype='object', length=294)

# %%
df.index[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-c8cba0a0215f> in <module>
# ----> 1 df.index['text:"RT @endgmez: Gente']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in __getitem__(self, key)
#     700         elif is_scalar(key):
#     701             raise IndexError(
# --> 702                 "only integers, slices (`:`), "
#     703                 "ellipsis (`...`), numpy.newaxis (`None`) "
#     704                 "and integer or boolean "
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
data = []
for i in range(0, len(df)):
    j=3
    s = df.index[i][j]
    data.append(s)
print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-b39a9808c8bd> in <module>
#       2 for i in range(0, len(df)):
#       3     j=3
# ----> 4     s = df.index[i][j]
#       5     data.append(s)
#       6 print(data)
#
# TypeError: 'int' object is not subscriptable

# %%
for tweet in data:
    #print(tweet)
    analysis = TextBlob(tweet)
    print(analysis.sentiment)
    """ if analysis.sentiment[0]>0:
        print('Positive')
    elif analysis.sentiment[0]<0:
        print('Negative')
    else:
        print('Neutral') """
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-4dab8bcf7233> in <module>
#       1 for tweet in data:
#       2     #print(tweet)
# ----> 3     analysis = TextBlob(tweet)
#       4     print(analysis.sentiment)
#       5     """ if analysis.sentiment[0]>0:
#
# NameError: name 'TextBlob' is not defined
